# %%
print("在vscode中新建notebook并测试运行")

print("第一行")
print("第二行")

total = 1 + 2 + 3 + \
      4 + 5
print(total)

fruits = ["苹果","香蕉",
          "橙子","葡萄"]
print(fruits)


#Tab键或者4个空格 表示缩进
if True:
    print("条件为真")
    print("继续执行")

# if True:
# print("缩进测试")    

'''
    这是一段多行备注
    第二行备注
    第三行备注
    第四行备注
'''
# Out:
# 在vscode中新建notebook并测试运行
# 第一行
# 第二行
# 15
# ['苹果', '香蕉', '橙子', '葡萄']
# 条件为真
# 继续执行
# '\n    这是一段多行备注\n    第二行备注\n    第三行备注\n    第四行备注\n'
